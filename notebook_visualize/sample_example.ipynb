# %%
import sys 
sys.path.append("..")

import matplotlib.pyplot as plt
from deepfly.GUI.CameraNetwork import CameraNetwork

import os 
print(os.getcwd())
image_folder = '../data/test'
output_folder = '../data/output'

camNet = CameraNetwork(image_folder=image_folder,output_folder=output_folder)

plt.imshow(camNet.cam_list[1].plot_2d())
# Out:
# C:\Users\ps\Desktop\djz\DeepFly3D_hubot\notebook_visualize

# %%
print(camNet.cam_list)
# Out:
# [<deepfly.GUI.Camera.Camera object at 0x000002321AAEA148>, <deepfly.GUI.Camera.Camera object at 0x000002321AAEA3C8>, <deepfly.GUI.Camera.Camera object at 0x000002321AAE5C48>]

# %%
import os 
print(os.getcwd())
# Out:
# C:\Users\ps\Desktop\djz\DeepFly3D_hubot\notebook_visualize

# %%
plt.imshow(camNet.cam_list[1].plot_heatmap(1))
# Out:
# Cannot find 1 1
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-813c7a663506> in <module>
# ----> 1 plt.imshow(camNet.cam_list[1].plot_heatmap(1))
#
# ~\Desktop\djz\DeepFly3D_hubot\deepfly\GUI\Camera.py in plot_heatmap(self, img_id, hm, img, concat, draw_joints, scale, flip_heatmap, flip_image)
#     340         """
#     341         if img is None:
# --> 342             inp = self.get_image(img_id, flip=flip_image)
#     343         else:
#     344             inp = img
#
# ~\Desktop\djz\DeepFly3D_hubot\deepfly\GUI\Camera.py in get_image(self, img_id, flip)
#     257         if img is None:
#     258             print("Cannot find", self.cam_id, img_id)
# --> 259             raise FileNotFoundError
#     260         img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#     261         if img.ndim == 2:
#
# FileNotFoundError:
